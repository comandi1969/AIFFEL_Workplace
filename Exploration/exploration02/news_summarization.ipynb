# %% [markdown]
# <a href="https://colab.research.google.com/github/LaVita337/AIFFEL_Workplace/blob/main/Quest/Quest06/news_summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 필요한 라이브러리 설치
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
# NLTK 데이터셋 다운로드
import os
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = pd.read_csv("/content/news_summarization/data/Reviews.csv", nrows=100000, skiprows=skip_rows)

print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 100000

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
data = data[['Text', 'Summary']]
data.head()

#랜덤한 15개 샘플 출력
data.sample(15)
# Out:
#                                                     Text  \
# 22587  My toddler son loves this mac and cheese.  My ...
# 43346  I have used the V8 Fusion juice since my son w...
# 17986  I have ordered this multiple times. Peanut But...
# 98598  You better like the taste of dates as that's a...
# 34228  We have purchased this treat for our dogs for ...
# 10038  I love this product, very convient serving pac...
# 23604  If you love really strong coffee you will more...
# 42996  As usual, Newman's own produces a superior kin...
# 92608  These chips are a nice break from the carbon c...
# 42641  My bulbs that I've been buying from HD the big...
# 68847  I can't get blueberries in Xiamen, China, wher...
# 66381  YUMM!! And it's Lactose, Gluten and Soy Free* ...
# 40388  This cereal has no artificial sweetners, is hi...
# 48628  got this as a test product in my influenster s...
# 14006  I own a 7 year old miniature Australian Sheppa...
#
#                                              Summary
# 22587                                         Yummy!
# 43346                                   Great juice!
# 17986                                    Always Good
# 98598                                            yuk
# 34228                         We call them "chewies"
# 10038                                   Quick & Easy
# 23604  When they say extra bold they aren't kidding!
# 42996             Mellow dark chocolate, very yummy.
# 92608                Tasty, goes well with most dips
# 42641           Better then the big box store lights
# 68847                    No Blues Over These Berries
# 66381                      Gotta' Have My Chocolate!
# 40388                                    Great Taste
# 48628                           tasty and nutritious
# 14006                                  Dog likes 'em

# %%
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['Text'].nunique())
print('Summary 열에서 중복을 배제한 유일한 샘플의 수 :', data['Summary'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 88426
# Summary 열에서 중복을 배제한 유일한 샘플의 수 : 72348

# %%
# inplace=True 를 설정하면 DataFrame 타입 값을 return 하지 않고 data 내부를 직접적으로 바꿉니다
data.drop_duplicates(subset = ['Text'], inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88426

# %%
# Null값 확인

print(data.isnull().sum())
# Out:
# Text       0
# Summary    1
# dtype: int64

# %%
# Null값 제거

data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88425

# %%
# 텍스트 정규화

contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
# 불용어 확인

print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# 데이터 전처리 함수
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah

    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'

print("text: ", preprocess_sentence(temp_text))
print("summary:", preprocess_sentence(temp_summary, False))  # 불용어를 제거하지 않습니다.
# Out:
# text:  everything bought great infact ordered twice third ordered wasfor mother father
# summary: great way to start the day

# %%
# 전체 Text 데이터에 대한 전처리 :
clean_text = []

clean_text = [preprocess_sentence(sentence) for sentence in data['Text']]


# 전처리 후 출력
print("Text 전처리 후 결과: ", clean_text[:5])
# Out:
# <ipython-input-47-165776f0a558>:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
# Text 전처리 후 결과:  ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better', 'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo', 'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch', 'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal', 'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
# NaN 값을 제거
data.dropna(subset=['Summary'], inplace=True)

# 전체 Summary 데이터에 대한 전처리
clean_summary = [preprocess_sentence(sentence, remove_stopwords=False) for sentence in data['Summary']]

# 전처리 후의 처음 5개 데이터 출력
clean_summary[:5]
# Out:
# <ipython-input-47-165776f0a558>:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
# <ipython-input-47-165776f0a558>:4: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy']

# %%
data['Text'] = clean_text
data['Summary'] = clean_summary

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)

# %%
# Null값 확인

data.isnull().sum()
# Out:
# Text        0
# Summary    70
# dtype: int64

# %%
# 빈 샘플 제거

data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88355

# %%
# 샘플의 최대 길이 정하기

# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['Text']]
summary_len = [len(s.split()) for s in data['Summary']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('Text')
plt.subplot(1,2,2)
plt.boxplot(summary_len)
plt.title('Summary')
plt.tight_layout()
plt.show()

plt.title('Text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 2
# 텍스트의 최대 길이 : 1235
# 텍스트의 평균 길이 : 38.79173787561542
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 28
# 요약의 평균 길이 : 4.010661535849697

# %%
text_max_len = 50
summary_max_len = 8

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, data['Text'])
below_threshold_len(summary_max_len,  data['Summary'])
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.774523230151095
# 전체 샘플 중 길이가 8 이하인 샘플의 비율: 0.9424593967517402

# %%
# text_max_len과 summary_max_len 변수 정의
text_max_len = 50
summary_max_len = 8

# text_max_len과 summary_max_len보다 길이가 큰 샘플을 제외하는 코드
data = data[data['Text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['Summary'].apply(lambda x: len(x.split()) <= summary_max_len)]

# 전체 샘플수 출력
len(data)
# Out:
# 65819

# %%
# 시작 토큰과 종료 토큰 추가하기

# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['Summary'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['Summary'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                                 Text                Summary  \
# 0  bought several vitality canned dog food produc...  good quality dog food
# 1  product arrived labeled jumbo salted peanuts p...      not as advertised
# 2  confection around centuries light pillowy citr...    delight says it all
# 3  looking secret ingredient robitussin believe f...         cough medicine
# 4  great taffy great price wide assortment yummy ...            great taffy
#
#                     decoder_input                  decoder_target
# 0  sostoken good quality dog food  good quality dog food eostoken
# 1      sostoken not as advertised      not as advertised eostoken
# 2    sostoken delight says it all    delight says it all eostoken
# 3         sostoken cough medicine         cough medicine eostoken
# 4            sostoken great taffy            great taffy eostoken

# %%
encoder_input = np.array(data['Text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [32263 62914 14766 ... 23097 43802 23733]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :', n_of_val)
# Out:
# 테스트 데이터의 수 : 13163

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 52656
# 훈련 레이블의 개수 : 52656
# 테스트 데이터의 개수 : 13163
# 테스트 레이블의 개수 : 13163

# %%
# 단어 집합(vocabulary) 만들기 및 정수 인코딩

src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 31900
# 등장 빈도가 6번 이하인 희귀 단어의 수: 23636
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 8264
# 단어 집합에서 희귀 단어의 비율: 74.09404388714734
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.3802545876967947

# %%
src_vocab = 8000
src_tokenizer = Tokenizer(num_words=src_vocab) # 단어 집합의 크기를 8,000으로 제한
src_tokenizer.fit_on_texts(encoder_input_train) # 단어 집합 재생성

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train)
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# 잘 진행되었는지 샘플 출력
print(encoder_input_train[:3])
# Out:
# [[16, 118, 30, 1063, 86, 4, 2980, 906, 1689, 11, 13, 109, 24, 205, 114, 1459, 949, 37, 1689, 409, 4, 1309, 7185, 2520, 140, 1, 244, 16, 2, 533, 30, 3805, 86, 306, 943, 2285, 263, 1689, 4486, 334], [356, 371, 502, 1302, 6789, 2005, 3076, 255, 898, 851, 1381, 358, 755, 7, 633, 108, 2615, 448, 851, 1241, 3975, 129, 153, 2030, 207, 1, 1, 1235, 9, 591, 591], [3, 960, 175, 19, 3197, 416, 960, 31, 1303, 293, 960, 259, 14, 1111, 175, 19, 659, 56, 506, 33, 196, 2397, 19, 1707, 999, 1652, 38, 136, 3242, 58, 20, 14, 3, 221, 19, 1916, 5886, 1325, 146, 77, 1718, 245]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 10557
# 등장 빈도가 5번 이하인 희귀 단어의 수: 8176
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 2381
# 단어 집합에서 희귀 단어의 비율: 77.44624419816236
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 5.926363287664149

# %%
tar_vocab = 2000
tar_tokenizer = Tokenizer(num_words=tar_vocab)
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train)
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 6, 65, 149], [1, 261], [1, 3, 75, 35], [1, 952, 62], [1, 69, 7, 11, 25]]
# target
# decoder  [[6, 65, 149, 2], [261, 2], [3, 75, 35, 2], [952, 62, 2], [69, 7, 11, 25, 2]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 1263
# 삭제할 테스트 데이터의 개수 : 356
# 훈련 데이터의 개수 : 51393
# 훈련 레이블의 개수 : 51393
# 테스트 데이터의 개수 : 12807
# 테스트 레이블의 개수 : 12807

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen=summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=summary_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen=summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=summary_max_len, padding='post')

# %%
# 모델 설계하기

from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
# encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
# decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 50)]                 0         []
#
#  embedding (Embedding)       (None, 50, 128)              1024000   ['input_1[0][0]']
#
#  lstm (LSTM)                 [(None, 50, 256),            394240    ['embedding[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 50, 256),            525312    ['lstm[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  embedding_1 (Embedding)     (None, None, 128)            256000    ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 50, 256),            525312    ['lstm_1[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  lstm_3 (LSTM)               [(None, None, 256),          394240    ['embedding_1[0][0]',
#                               (None, 256),                           'lstm_2[0][1]',
#                               (None, 256)]                           'lstm_2[0][2]']
#
#  dense (Dense)               (None, None, 2000)           514000    ['lstm_3[0][0]']
#
# ==================================================================================================
# Total params: 3633104 (13.86 MB)
# Trainable params: 3633104 (13.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.layers import AdditiveAttention

# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_outputs])


# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 50)]                 0         []
#
#  embedding (Embedding)       (None, 50, 128)              1024000   ['input_1[0][0]']
#
#  lstm (LSTM)                 [(None, 50, 256),            394240    ['embedding[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 50, 256),            525312    ['lstm[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  embedding_1 (Embedding)     (None, None, 128)            256000    ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 50, 256),            525312    ['lstm_1[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  lstm_3 (LSTM)               [(None, None, 256),          394240    ['embedding_1[0][0]',
#                               (None, 256),                           'lstm_2[0][1]',
#                               (None, 256)]                           'lstm_2[0][2]']
#
#  attention_layer (AdditiveA  (None, None, 256)            256       ['lstm_3[0][0]',
#  ttention)                                                           'lstm_2[0][0]']
#
#  concat_layer (Concatenate)  (None, None, 512)            0         ['lstm_3[0][0]',
#                                                                      'attention_layer[0][0]']
#
#  dense_1 (Dense)             (None, None, 2000)           1026000   ['concat_layer[0][0]']
#
# ==================================================================================================
# Total params: 4145360 (15.81 MB)
# Trainable params: 4145360 (15.81 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# 모델 훈련하기

model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=256, callbacks=[es], epochs=50)
# Out:
# Epoch 1/50
# 201/201 [==============================] - 51s 188ms/step - loss: 2.8986 - val_loss: 2.5721
# Epoch 2/50
# 201/201 [==============================] - 20s 100ms/step - loss: 2.5404 - val_loss: 2.4978
# Epoch 3/50
# 201/201 [==============================] - 18s 90ms/step - loss: 2.4604 - val_loss: 2.4600
# Epoch 4/50
# 201/201 [==============================] - 16s 80ms/step - loss: 2.3979 - val_loss: 2.3769
# Epoch 5/50
# 201/201 [==============================] - 16s 77ms/step - loss: 2.3498 - val_loss: 2.3394
# Epoch 6/50
# 201/201 [==============================] - 16s 78ms/step - loss: 2.3103 - val_loss: 2.3107
# Epoch 7/50
# 201/201 [==============================] - 15s 75ms/step - loss: 2.2746 - val_loss: 2.2790
# Epoch 8/50
# 201/201 [==============================] - 15s 77ms/step - loss: 2.2366 - val_loss: 2.2491
# Epoch 9/50
# 201/201 [==============================] - 15s 74ms/step - loss: 2.1985 - val_loss: 2.2052
# Epoch 10/50
# 201/201 [==============================] - 14s 69ms/step - loss: 2.1628 - val_loss: 2.1770
# Epoch 11/50
# 201/201 [==============================] - 14s 71ms/step - loss: 2.1290 - val_loss: 2.1585
# Epoch 12/50
# 201/201 [==============================] - 14s 69ms/step - loss: 2.1011 - val_loss: 2.1336
# Epoch 13/50
# 201/201 [==============================] - 14s 70ms/step - loss: 2.0757 - val_loss: 2.1214
# Epoch 14/50
# 201/201 [==============================] - 14s 72ms/step - loss: 2.0527 - val_loss: 2.1056
# Epoch 15/50
# 201/201 [==============================] - 14s 70ms/step - loss: 2.0309 - val_loss: 2.0821
# Epoch 16/50
# 201/201 [==============================] - 14s 70ms/step - loss: 2.0106 - val_loss: 2.0699
# Epoch 17/50
# 201/201 [==============================] - 14s 72ms/step - loss: 1.9903 - val_loss: 2.0500
# Epoch 18/50
# 201/201 [==============================] - 15s 72ms/step - loss: 1.9718 - val_loss: 2.0388
# Epoch 19/50
# 201/201 [==============================] - 14s 71ms/step - loss: 1.9518 - val_loss: 2.0235
# Epoch 20/50
# 201/201 [==============================] - 14s 71ms/step - loss: 1.9345 - val_loss: 2.0186
# Epoch 21/50
# 201/201 [==============================] - 14s 70ms/step - loss: 1.9172 - val_loss: 2.0103
# Epoch 22/50
# 201/201 [==============================] - 14s 70ms/step - loss: 1.9014 - val_loss: 2.0016
# Epoch 23/50
# 201/201 [==============================] - 15s 74ms/step - loss: 1.8866 - val_loss: 1.9881
# Epoch 24/50
# 201/201 [==============================] - 15s 75ms/step - loss: 1.8712 - val_loss: 1.9830
# Epoch 25/50
# 201/201 [==============================] - 14s 70ms/step - loss: 1.8565 - val_loss: 1.9815
# Epoch 26/50
# 201/201 [==============================] - 14s 71ms/step - loss: 1.8423 - val_loss: 1.9669
# Epoch 27/50
# 201/201 [==============================] - 15s 72ms/step - loss: 1.8277 - val_loss: 1.9717
# Epoch 28/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.8138 - val_loss: 1.9565
# Epoch 29/50
# 201/201 [==============================] - 14s 70ms/step - loss: 1.7996 - val_loss: 1.9554
# Epoch 30/50
# 201/201 [==============================] - 15s 74ms/step - loss: 1.7867 - val_loss: 1.9436
# Epoch 31/50
# 201/201 [==============================] - 15s 73ms/step - loss: 1.7725 - val_loss: 1.9451
# Epoch 32/50
# 201/201 [==============================] - 14s 70ms/step - loss: 1.7604 - val_loss: 1.9439
# Epoch 32: early stopping

# %%
# 시각화

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# 인퍼런스 모델 구현하기

src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat)

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp = ''
    for i in input_seq:
        if (i != 0 and i != tar_word_to_index['sostoken'] and i != tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

seq2summary
# Out:
# <function __main__.seq2summary(input_seq)>

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : new gluten free world still options certainly good choice like blueberry lemon flavors exactly taste like soft cookie nothing bad say tried gluten free market among better choices friend year old really liked gave box
# 실제 요약 : still getting used to gluten free foods
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  not bad
#
#
# 원문 : year old son loves banana yogurt taste like baby foods honest would eat cup
# 실제 요약 : yum
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  my son loves these
#
#
# 원문 : many making huge mess grounds cup onto counter first one thought maybe one bad one seen green mountain brand rarely maybe one boxes third one tossed remainder trash
# 실제 요약 : pods making huge mess
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 예측 요약 :  not bad
#
#
# 원문 : bees arrived expected packed super securely pictured problem tempting year old niece picked every single one cake ate even served dessert
# 실제 요약 : too
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약 :  great product
#
#
# 원문 : made switch coffee tea last year switch black green year mint jasmine tea right amount caffeine bright floral flavor delicious
# 실제 요약 : best morning tea ever
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약 :  great tea
#
#
# 원문 : drink teas time first time tried pumpkin think new favorite best price anywhere teas
# 실제 요약 : tea best tea
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 예측 요약 :  great tea
#
#
# 원문 : read someone review said hard keep fresh store food saver canister transfer lock lock container easy access would imagine would stay fresh used lock lock container dog loves love contain calories
# 실제 요약 : them fresh
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 예측 요약 :  not as good as the
#
#
# 원문 : excellent pre mix tastes like mother made without measuring mess delicious convenient would repurchase
# 실제 요약 : like mother made
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 예측 요약 :  great product
#
#
# 원문 : wow gluten dairy free diet ideal quick snack something keep purse box partner strict dietary needs seldom something available tastes good come cost digestive system perfect
# 실제 요약 : small of heaven
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  great gluten free
#
#
# 원문 : husband loves chocolate covered cherries tasted would eat kind small town could find christmas holidays valentines day found online keep hand year chocolate cherries happy hubby
# 실제 요약 : in love
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great snack
#
#
# 원문 : used ordering nibs grinding result richest chocolate one imagine hand left gritty texture pudding made bitter flavor could even major amounts sugar mild hint chocolate first time ever daughter said want chocolate pudding
# 실제 요약 : bitter and very poor taste
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  not bad
#
#
# 원문 : convenient product package fancy feast cat food convenient delivered front door comparable price cat food purchased local grocery store favorable way
# 실제 요약 : cat food
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  my cats love it
#
#
# 원문 : extra bold coffee one favorites extra bold could compared bold coffee regular coffee brewer
# 실제 요약 : great coffee for keurig brewer
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : son loves give knowing melt mouth choke good
# 실제 요약 : great snacks
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great snack
#
#
# 원문 : sauce one best tried used jarred well packaged book recipes sauce shines keep case pantry oz size never waste case jars good price premium sauce
# 실제 요약 : one of the best
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great product
#
#
# 원문 : product dry cut cat mouth cause bleeding choking product received petco dry bone could compared eating fish without first would feed family fish bones cats family maybe product received usual quality dry dry dry salmon equally dry
# 실제 요약 : this stuff is dangerous
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  cats love it
#
#
# 원문 : best tasting protein shake ever tried pretty lean calories per gram protein chocolate ice cream vanilla ice cream cookies cream good like vanilla best shakes make dieting lot pleasant reducing hunger keeping protein intake even calories reduced
# 실제 요약 : tastes like yellow cake
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  delicious
#
#
# 원문 : glad find hot sauce amazon used buy ton drove rocky point mexico hot sauce found makes everything taste great
# 실제 요약 : the best hot sauce ever
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 예측 요약 :  great product
#
#
# 원문 : found wonderful treats pet store dogs love could find pet stores locally went internet thank heaven able find better price
# 실제 요약 : treats
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  great treats
#
#
# 원문 : really good tasting chips unhealthy eat fair amount love flavoring
# 실제 요약 : great tasting chips alternative
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  great chips
#
#
# 원문 : comes like mush right bag reason even gets two stars convenience
# 실제 요약 : disgusting
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great product
#
#
# 원문 : simply put tea incredible would say like tea never really crave tea except one cup hand sitting leather find relaxation flavor rich distinctive couple cups time nearly taste thinking confusing fan bitter flavors brew dark drink straight love surprised price seems inexpensive
# 실제 요약 : tea that me in good way
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great tea
#
#
# 원문 : sons love pasta personally think tinkyada pastas taste better kids like much think fun animal shapes make appealing love letter shaped pasta well wish company made pasta size larger though kids liked smaller size better oh well still like thrilled found amazon local moms store stopped carrying quite time
# 실제 요약 : great for kids
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  great pasta
#
#
# 원문 : introduced product shop california would steak place put ziplock bag marinate really brings good flavor bbq meat soaked spices part really like contain msg
# 실제 요약 : is great for bbq
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  great flavor
#
#
# 원문 : dogs love put kong toy keeps busy moments good
# 실제 요약 : yummy
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  dogs love them
#
#
# 원문 : would never buy product hulls equal amount popcorn would much better without stuff product probably come bonus pack dental floss maybe discounted coupon water pick
# 실제 요약 : omg
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  not as good as expected
#
#
# 원문 : know long sat back shelf somewhere old would cook throw half skins damaged clear sign dried beans past prime cannot even return ask refund food returnable find different brand use fifty servings beans throw away
# 실제 요약 : very low quality
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  not as advertised
#
#
# 원문 : recently discovered ginger beer like ginger ale spicy gingery picked sounded like spicy good price found sweet grams sugar per serving like fever tree premium ginger beer ounce glass bottles much better
# 실제 요약 : good but
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  not bad
#
#
# 원문 : coffee outstanding concept wonderful order kcups adds disappointed otherwise would rated five stars
# 실제 요약 : count the cups
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : dog vet trying sell dental cleaning long time really dog finally vet told see substantial improvement using dental treat daily dog loves dentastix seen tartar begin disappear going give treat anyway might well give one teeth time
# 실제 요약 : affordable teeth
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  dog loves it
#
#
# 원문 : ordered item children church easter church events children important take seriously item items ordered amazon com saved bunches money purchased elsewhere knows
# 실제 요약 : fresh shipping great prices
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  great product
#
#
# 원문 : purchased chips since much cheaper cost grocery expire months first bags ate stale plus many broken wrote amazon give prompt refund customer service excellent since opened bags seem stale still believe taste fresh ones grocery may try reordering since good deal hopefully give better review next time
# 실제 요약 : chips were stale but my money was
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 예측 요약 :  not as good as the
#
#
# 원문 : good stuff maybe little hard guess real granola nice vanilla yogurt mixed granola cereal resealable packaging makes sure turn big pile mush
# 실제 요약 : good stuff
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  not good
#
#
# 원문 : purchased popcorn along popcorn machine church events could happier fact packages contain oil seasoning popcorn one great feature seasoning perfect everyone events loves gets positive comments great item great value
# 실제 요약 : great popcorn great value
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great popcorn
#
#
# 원문 : addicting tastes good particularly like tiny mint leaves candy complaint artificial flavors natural flavors might natural good mints tough find ones natural like
# 실제 요약 : natural mints
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  not so good
#
#
# 원문 : thin crisp fragrant cookies delicious tasty excellent glass cold almond milk hot herbal tea like ginger snaps love ginger snaps
# 실제 요약 : delicious
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약 :  delicious
#
#
# 원문 : favorite chai drink almost every day work flavor great big tin nice includes perfect sized scoop make cup nice tin instead individual packets add reduce amount powder according preference perfect morning afternoon treat
# 실제 요약 : delicious and easy to make
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  great tea
#
#
# 원문 : today january th description says incorrect currently unit price comes pack probably expensive local grocery stores value pack
# 실제 요약 : incorrect description
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  not as pictured
#
#
# 원문 : mixed terrier dogs prefer treat others one dogs cabinet stored wanting
# 실제 요약 : these are amazing treats and great value
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  dogs love them
#
#
# 원문 : taste gluten free breads leave blah taste except one excellent taste texture let us daughter enjoy bread family makes great pizza
# 실제 요약 : gluten free bread that actually tastes good
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# 예측 요약 :  great gluten free pasta
#
#
# 원문 : royal oak gourmet virginia raw shell peanuts pound bags appreciate speedy deliver package however sent raw peanuts without shell item going gift basket love raw peanuts shell time returned requested product always prompt orders past really appreciate first time sent incorrect product make work
# 실제 요약 : incorrect order
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 예측 요약 :  great product
#
#
# 원문 : product excellent customer service good recommended product several people
# 실제 요약 : madhava organic nectar
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 예측 요약 :  great product
#
#
# 원문 : wonderful product add teaspoon cup lemonade adjust taste thanks
# 실제 요약 : strawberry lemonade all summer
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 예측 요약 :  great product
#
#
# 원문 : product perfect daughter th grade report germany gave away gummi bears show sampling german product lots bears great price
# 실제 요약 : great bears great price
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 예측 요약 :  great product
#
#
# 원문 : perfect size snack bag school minus one star glue straws also wrapper boxes annoying
# 실제 요약 : perfect for snack bag
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 예측 요약 :  delicious
#
#
# 원문 : bear great like kind get novelty candy stores much cheaper lb opinion flavors gummy bears much better haribo bears experienced powdery residue melted previous reviewers bears came perfect condition perfect packaging like mini gummy bears suggest give try
# 실제 요약 : delicious little gummy bears
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 21ms/step
# 예측 요약 :  great product
#
#
# 원문 : using product dishes call white rice rice mix daughter liked really well second seasoning quite like recipes tried good work seasoning liked idea something cooked quickly whole wheat organic etc
# 실제 요약 : whole wheat pasta
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great for
#
#
# 원문 : seemed like good deal time found better deals local
# 실제 요약 : pricey
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약 :  great product
#
#
# 원문 : gevalia coffees favorite large cup morning look forward every day tastes great even one evening coffees satisfies coffee craving probably third fourth time ordering morning roast continue order coffee
# 실제 요약 : my favorite coffee
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : caution use ice cubes zevia soda hooked zevia sodas tastes heavy flavored soda seems right amount taste add ice taste seems get watered zevia new soda choice
# 실제 요약 : great taste
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 예측 요약 :  great flavor

# %%
# 추출적 요약

# 패키지 설치
# !pip list | grep summa
# !pip install summa
# Out:
# torchsummary                     1.5.1
# Collecting summa
#   Downloading summa-1.2.0.tar.gz (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.10/dist-packages (from summa) (1.11.2)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy>=0.19->summa) (1.23.5)
# Building wheels for collected packages: summa
#   Building wheel for summa (setup.py) ... done
#   Created wheel for summa: filename=summa-1.2.0-py3-none-any.whl size=54389 sha256=5374743d683114fac1e8eeacc7e5cae304b214888d010bdb2735b084b70592ed
#   Stored in directory: /root/.cache/pip/wheels/4a/ca/c5/4958614cfba88ed6ceb7cb5a849f9f89f9ac49971616bc919f
# Successfully built summa
# Installing collected packages: summa
# Successfully installed summa-1.2.0

# %%
# 데이터 다운로드

import requests
from summa.summarizer import summarize

# %%
# 매트릭스 시놉시스 다운
text = requests.get('http://rare-technologies.com/the_matrix_synopsis.txt').text

# %%
print(text[:1500])
# Out:
# The screen is filled with green, cascading code which gives way to the title, The Matrix.
#
# A phone rings and text appears on the screen: "Call trans opt: received. 2-19-98 13:24:18 REC: Log>" As a conversation takes place between Trinity (Carrie-Anne Moss) and Cypher (Joe Pantoliano), two free humans, a table of random green numbers are being scanned and individual numbers selected, creating a series of digits not unlike an ordinary phone number, as if a code is being deciphered or a call is being traced.
#
# Trinity discusses some unknown person. Cypher taunts Trinity, suggesting she enjoys watching him. Trinity counters that "Morpheus (Laurence Fishburne) says he may be 'the One'," just as the sound of a number being selected alerts Trinity that someone may be tracing their call. She ends the call.
#
# Armed policemen move down a darkened, decrepit hallway in the Heart O' the City Hotel, their flashlight beam bouncing just ahead of them. They come to room 303, kick down the door and find a woman dressed in black, facing away from them. It's Trinity. She brings her hands up from the laptop she's working on at their command.
#
# Outside the hotel a car drives up and three agents appear in neatly pressed black suits. They are Agent Smith (Hugo Weaving), Agent Brown (Paul Goddard), and Agent Jones (Robert Taylor). Agent Smith and the presiding police lieutenant argue. Agent Smith admonishes the policeman that they were given specific orders to contact the agents first, for their

# %%
# summarize 사용하기

print('Summary:')
print(summarize(text, ratio=0.005))
# Out:
# Summary:
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.

# %%
print('Summary:')
print(summarize(text, ratio=0.005, split=True))
# Out:
# Summary:
# ['Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.', 'Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.']

# %%
print('Summary:')
print(summarize(text, words=50))
# Out:
# Summary:
# Trinity takes Neo to Morpheus.
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.

# %% [markdown]
# # **Project: News Summarization**

# %%
from importlib.metadata import version
import nltk
import tensorflow
import summa
import pandas as pd

print(nltk.__version__)
print(tensorflow.__version__)
print(pandas.__version__)
print(version('summa'))
# Out:
# 3.8.1
# 2.13.0
# 1.5.3
# 1.2.0

# %%
# 데이터 수집

import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv", filename="news_summary_more.csv")
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')

# %%
data.sample(10)
# Out:
#                                                headlines  \
# 73685  Brazil's WC winner sentenced to jail for unpai...
# 30224  'Rustom' writer files case against 'Batti Gul ...
# 60045  2 'rich' women among beggars being shifted to ...
# 63763    Ã¢ÂÂ¹2,270 crore Legoland to come up in the US
# 57624  UN rejects US' recognition of Jerusalem as Isr...
# 52508  Three men wiped $3 bn off South African stocks...
# 55091  Terror caused by foreign interference in Pak: ...
# 49713  Govt announces Ã¢ÂÂ¹10,000 crore for fisherie...
# 4839   PETA India backs Centre's proposal to ban anim...
# 65161  He knew what he signed up for: Trump told sold...
#
#                                                     text
# 73685  Brazil's 2002 FIFA World Cup-winning player Ro...
# 30224  'Rustom' writer Vipul Rawal has filed a copyri...
# 60045  The Hyderabad Police has found two 'rich, educ...
# 63763  British firm Merlin Entertainments has announc...
# 57624  After US President Donald Trump on Wednesday r...
# 52508  Over $3 billion was wiped off from the value o...
# 55091  In an apparent attack on the US, Pakistan Pres...
# 49713  Finance Minister Arun Jaitley on Thursday anno...
# 4839   Animal rights organisation PETA India on Monda...
# 65161  US President Donald Trump told the widow of an...

# %%
# 데이터 불러오기
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')

# 텍스트 정규화 및 정제
contractions = { ... } # 위에서 제공된 contractions 딕셔너리 사용

def preprocess_text(sen, remove_stopwords=True):
    # 텍스트 정규화
    sen = ' '.join([contractions[t] if t in contractions else t for t in sen.split(" ")])
    # HTML 태그 제거
    sen = BeautifulSoup(sen, "html.parser").get_text()
    # 특수문자 제거
    sen = re.sub('\([^)]*\)', '', sen)
    sen = re.sub('"', '', sen)
    sen = ' '.join([contractions[t] if t in contractions else t for t in sen.split(" ")])
    sen = re.sub(r"'s\b", "", sen)
    sen = re.sub("[^a-zA-Z]", " ", sen)
    sen = re.sub('[m]{2,}', 'mm', sen)
    if remove_stopwords:
        sen = ' '.join(word for word in sen.split() if not word in stopwords.words('english'))
    return sen

clean_text = [preprocess_text(t) for t in data['text']]
clean_summary = [preprocess_text(t, remove_stopwords=False) for t in data['headlines']]
# Out:
# <ipython-input-102-f6ea36cd00b1>:11: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   sen = BeautifulSoup(sen, "html.parser").get_text()

# %%
# 단어의 토큰화 및 정수 인코딩

# 단어 토큰화
text_tokenizer = Tokenizer()
text_tokenizer.fit_on_texts(clean_text)
text_data = text_tokenizer.texts_to_sequences(clean_text)

summary_tokenizer = Tokenizer()
summary_tokenizer.fit_on_texts(clean_summary)
summary_data = summary_tokenizer.texts_to_sequences(clean_summary)

# 패딩
text_data = pad_sequences(text_data, maxlen=text_max_len, padding='post')
summary_data = pad_sequences(summary_data, maxlen=summary_max_len, padding='post')

# %% [markdown]
# ### **어텐션 메커니즘 사용하기 (추상적 요약)**

# %%
# 어텐션 매커니즘을 위한 클래스 정의:

import tensorflow as tf
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K

class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
    """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state """

            assert_msg = "States must be a list. However states {} is of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch_size*en_seq_len, latent_dim
            reshaped_enc_outputs = K.reshape(encoder_out_seq, (-1, en_hidden))
            # <= batch_size*en_seq_len, latent_dim
            W_a_dot_s = K.reshape(K.dot(reshaped_enc_outputs, self.W_a), (-1, en_seq_len, en_hidden))
            if verbose:
                print('wa.s>',W_a_dot_s.shape)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>',U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            reshaped_Ws_plus_Uh = K.tanh(K.reshape(W_a_dot_s + U_a_dot_h, (-1, en_hidden)))
            if verbose:
                print('Ws+Uh>', reshaped_Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.reshape(K.dot(reshaped_Ws_plus_Uh, self.V_a), (-1, en_seq_len))
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """
            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        def create_inital_state(inputs, hidden_size):
            # We are not using initial states, but need to pass something to K.rnn funciton
            fake_state = K.zeros_like(inputs)  # <= (batch_size, enc_seq_len, latent_dim
            fake_state = K.sum(fake_state, axis=[1, 2])  # <= (batch_size)
            fake_state = K.expand_dims(fake_state)  # <= (batch_size, 1)
            fake_state = K.tile(fake_state, [1, hidden_size])  # <= (batch_size, latent_dim
            return fake_state

        fake_state_c = create_inital_state(encoder_out_seq, encoder_out_seq.shape[-1])
        fake_state_e = create_inital_state(encoder_out_seq, encoder_out_seq.shape[1])  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_outputs, state_h, state_c = encoder_lstm3(encoder_output2)

# 디코더 설계

decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

# 어텐션 메커니즘
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# 모델 훈련
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
history = model.fit([encoder_input_train, decoder_input_train], decoder_target_train,
          epochs=50,
          callbacks=[es],
          batch_size=256,
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test))
# Out:
# Epoch 1/50
# 201/201 [==============================] - 197s 911ms/step - loss: 2.8949 - val_loss: 2.5852
# Epoch 2/50
# 201/201 [==============================] - 167s 832ms/step - loss: 2.5345 - val_loss: 2.4920
# Epoch 3/50
# 201/201 [==============================] - 160s 796ms/step - loss: 2.4692 - val_loss: 2.4568
# Epoch 4/50
# 201/201 [==============================] - 157s 783ms/step - loss: 2.4299 - val_loss: 2.4149
# Epoch 5/50
# 201/201 [==============================] - 156s 775ms/step - loss: 2.3721 - val_loss: 2.3566
# Epoch 6/50
# 201/201 [==============================] - 160s 792ms/step - loss: 2.3256 - val_loss: 2.3160
# Epoch 7/50
# 201/201 [==============================] - 160s 797ms/step - loss: 2.2919 - val_loss: 2.2943
# Epoch 8/50
# 201/201 [==============================] - 166s 825ms/step - loss: 2.2606 - val_loss: 2.2668
# Epoch 9/50
# 201/201 [==============================] - 158s 787ms/step - loss: 2.2313 - val_loss: 2.2375
# Epoch 10/50
# 201/201 [==============================] - 158s 786ms/step - loss: 2.2018 - val_loss: 2.2146
# Epoch 11/50
# 201/201 [==============================] - 164s 813ms/step - loss: 2.1741 - val_loss: 2.1816
# Epoch 12/50
# 201/201 [==============================] - 164s 811ms/step - loss: 2.1478 - val_loss: 2.1661
# Epoch 13/50
# 201/201 [==============================] - 165s 819ms/step - loss: 2.1224 - val_loss: 2.1392
# Epoch 14/50
# 201/201 [==============================] - 167s 831ms/step - loss: 2.0986 - val_loss: 2.1203
# Epoch 15/50
# 201/201 [==============================] - 164s 816ms/step - loss: 2.0734 - val_loss: 2.1056
# Epoch 16/50
# 201/201 [==============================] - 165s 822ms/step - loss: 2.0521 - val_loss: 2.0879
# Epoch 17/50
# 201/201 [==============================] - 156s 776ms/step - loss: 2.0269 - val_loss: 2.0722
# Epoch 18/50
# 201/201 [==============================] - 151s 753ms/step - loss: 2.0042 - val_loss: 2.0488
# Epoch 19/50
# 201/201 [==============================] - 150s 747ms/step - loss: 1.9835 - val_loss: 2.0291
# Epoch 20/50
# 201/201 [==============================] - 152s 756ms/step - loss: 1.9650 - val_loss: 2.0233
# Epoch 21/50
# 201/201 [==============================] - 151s 751ms/step - loss: 1.9464 - val_loss: 2.0131
# Epoch 22/50
# 201/201 [==============================] - 159s 790ms/step - loss: 1.9310 - val_loss: 2.0011
# Epoch 23/50
# 201/201 [==============================] - 166s 825ms/step - loss: 1.9159 - val_loss: 1.9929
# Epoch 24/50
# 201/201 [==============================] - 164s 815ms/step - loss: 1.9019 - val_loss: 1.9849
# Epoch 25/50
# 201/201 [==============================] - 162s 807ms/step - loss: 1.8874 - val_loss: 1.9842
# Epoch 26/50
# 201/201 [==============================] - 155s 769ms/step - loss: 1.8745 - val_loss: 1.9705
# Epoch 27/50
# 201/201 [==============================] - 155s 772ms/step - loss: 1.8605 - val_loss: 1.9668
# Epoch 28/50
# 201/201 [==============================] - 154s 766ms/step - loss: 1.8471 - val_loss: 1.9565
# Epoch 29/50
# 201/201 [==============================] - 154s 764ms/step - loss: 1.8329 - val_loss: 1.9515
# Epoch 30/50
# 201/201 [==============================] - 152s 758ms/step - loss: 1.8198 - val_loss: 1.9455
# Epoch 31/50
# 201/201 [==============================] - 155s 774ms/step - loss: 1.8073 - val_loss: 1.9388
# Epoch 32/50
# 201/201 [==============================] - 168s 835ms/step - loss: 1.7947 - val_loss: 1.9343
# Epoch 33/50
# 201/201 [==============================] - 159s 794ms/step - loss: 1.7819 - val_loss: 1.9342
# Epoch 34/50
# 201/201 [==============================] - 154s 766ms/step - loss: 1.7690 - val_loss: 1.9271
# Epoch 35/50
# 201/201 [==============================] - 159s 789ms/step - loss: 1.7577 - val_loss: 1.9311
# Epoch 36/50
# 201/201 [==============================] - 159s 790ms/step - loss: 1.7448 - val_loss: 1.9196
# Epoch 37/50
# 201/201 [==============================] - 155s 771ms/step - loss: 1.7347 - val_loss: 1.9183
# Epoch 38/50
# 201/201 [==============================] - 157s 783ms/step - loss: 1.7226 - val_loss: 1.9204
# Epoch 39/50
# 201/201 [==============================] - 163s 808ms/step - loss: 1.7115 - val_loss: 1.9159
# Epoch 40/50
# 201/201 [==============================] - 161s 804ms/step - loss: 1.7016 - val_loss: 1.9123
# Epoch 41/50
# 201/201 [==============================] - 153s 762ms/step - loss: 1.6901 - val_loss: 1.9127
# Epoch 42/50
# 201/201 [==============================] - 152s 755ms/step - loss: 1.6793 - val_loss: 1.9102
# Epoch 43/50
# 201/201 [==============================] - 151s 753ms/step - loss: 1.6684 - val_loss: 1.9081
# Epoch 44/50
# 201/201 [==============================] - 158s 788ms/step - loss: 1.6588 - val_loss: 1.9106
# Epoch 45/50
# 201/201 [==============================] - 161s 800ms/step - loss: 1.6487 - val_loss: 1.9075
# Epoch 46/50
# 201/201 [==============================] - 161s 803ms/step - loss: 1.6388 - val_loss: 1.9078
# Epoch 47/50
# 201/201 [==============================] - 155s 773ms/step - loss: 1.6287 - val_loss: 1.9094
# Epoch 47: early stopping

# %%
# 1. 인퍼런스 모델 구성

# 인코더 인퍼런스 모델
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 디코더 인퍼런스 모델
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))

# 임베딩 층
dec_emb2 = dec_emb_layer(decoder_inputs)

# LSTM 층
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# 어텐션 메커니즘
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# Dense softmax 층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat)

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input, decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# 2. decode_sequence 함수 정의
def decode_sequence(input_seq):
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token != 'eostoken'):
            decoded_sentence += ' ' + sampled_token

        if (sampled_token == 'eostoken' or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        e_h, e_c = h, c

    return decoded_sentence

# 3. 원래의 요약문과 생성된 요약문 비교

for i in range(100):  # 테스트 데이터셋에서 처음 100개의 예제에 대해 실제 요약과 생성된 요약을 비교
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : bags cookies crackers great snack go etc calories calories depending variety would much rather half bag whole bag calorie crappy tasting diet snacks real fudge real cheez bite size love price great
# 실제 요약 : not to like
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 643ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 예측 요약 :  great gluten free snack
#
#
# 원문 : excellent brown rice brand type rice pleased texture flavor consistency second time buying extra long brown rice continue buy
# 실제 요약 : extra long grain brown rice
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약 :  great rice
#
#
# 원문 : really like fruity taste tea much actually drink without sugar like fruity teas try product
# 실제 요약 : great fruity taste
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  good tea
#
#
# 원문 : diet root beer earned rock solid four stars reason star recall authentic root beers reserve ultimate rating beverage delivers crisp clear creamy taste discernible try stuff like delivered door cents pop cannot go awfully wrong
# 실제 요약 : good root
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  not what expected
#
#
# 원문 : really best tea awful either good feel cup tea anything else
# 실제 요약 : it is okay
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  not what expected
#
#
# 원문 : dad absolute favorite candy loved orange bittersweet chocolate best flavors match made heaven adore well dad passed away found stash cupboard easy find make welcome dinner sweet coffee guests
# 실제 요약 : crisp chocolate and tender orange
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  great chocolate
#
#
# 원문 : purchased tea recommended helping women symptoms symptoms one cup cannot say helped symptoms purchased teas brand would recommend teas crazy taste red clover personal opinion little bitter bearable add sugar good go
# 실제 요약 : red tea
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  good tea
#
#
# 원문 : yr old fussy appetite used wellness many well known brands used past past pets loves blue buffalo also purchased blue buffalo cat loves also natural grain products protein beginning list corn oil etc price comparable name brands
# 실제 요약 : my
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  great for my dog
#
#
# 원문 : bought sale turned super disappointment like others said edible feel called salty absolute salt wash hot water minutes eat mess
# 실제 요약 : it is not salty it is salt
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  not what expected
#
#
# 원문 : may good sea sickness motion sickness morning sickness used find good sore throats congestion almost good ginger tea bad tasting either
# 실제 요약 : good for and too
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  great product
#
#
# 원문 : anytime mr greenie four dogs come running ages dogs love seem help breath tarter amazon absolute best prices
# 실제 요약 : what my dogs have to say
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great product
#
#
# 원문 : absolutly delicious ordered several times always fresh tasty freeze mine cuz like word lol nuts drive nuts eat great snack healthy eat
# 실제 요약 : am nutty over these
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great snack
#
#
# 원문 : funky flavour really get fingers bought eat driving going work
# 실제 요약 : just ok
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  not bad
#
#
# 원문 : pup absolutely loved soon saw though treats gotten bit big size gotten fun pup even without anything
# 실제 요약 : doggy approved
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  my loves these
#
#
# 원문 : read weight loss among benefits thought would try make sure know related tomato chili pepper normal berry taste like bit dried tomato sweet fruit easy lose weight taste like dried tomato make available food
# 실제 요약 : berries for weight loss
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  good but not great
#
#
# 원문 : pamela gluten free bread best miles ahead gluten free brands bread delicious moist use bread maker add raisins cranberries enhance bread also excellent toasted
# 실제 요약 : delicious bread
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  best gluten free bread mix
#
#
# 원문 : following plant based diet use tofu almost daily expensive purchase store takes valuable real fridge packages sit perfectly shelf little smaller standard refrigerated tofu also silk tofu hold shape well good certain things like fried rice chocolate mousse great making tofu steaks strips
# 실제 요약 : convenient
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  amazing
#
#
# 원문 : know many people say lot artificial sweeteners taste like sugar sprinkle little hand taste amazing much taste like sugar would given stars sugar came box price
# 실제 요약 : taste like sugar
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  great sugar substitute
#
#
# 원문 : healthy excellant taste sure kids would love also year old grandson much better cereals protein fiber great deal next grocery store
# 실제 요약 : love it
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  great for breakfast
#
#
# 원문 : tried love perfect refreshing soda however sister added glass tasted like wonderful going snap keep hand add red wine love taste red wine add little fruit voila
# 실제 요약 : so good
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 40ms/step
# 예측 요약 :  best drink ever
#
#
# 원문 : sure anyone said coffee fit ekobrew cup fits even room bit trying doughnut shop blend west coast blend family enjoys west coast blend flavor also nice
# 실제 요약 : very good but blend is better
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : even though sealed individual packages nice seems like retain freshness sticks got like shoe leather little taste would purchase think flavor since sealed freshness also sticks get hard
# 실제 요약 : could stay little since sealed
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  not bad
#
#
# 원문 : also ordering line hard find gluten free yo eats constantly however first case came broken cakes top layer bags try tho love convenience drive town keep house
# 실제 요약 : hard to find
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great gluten free baking
#
#
# 원문 : originally found big lots store like mustard thought would go well others fridge boy became favorite even huge mustard person ran bought case started giving jars away stuff best brats grilled sausages try love
# 실제 요약 : mm mustard
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  love this stuff
#
#
# 원문 : although love tea always avoided herbal floral ones something description hibiscus tea package came beautifully wrapped anyway important thing taste delightful hot cold nice fruity sweet luv
# 실제 요약 : hibiscus tea
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  great tea
#
#
# 원문 : little skeptical bought really great purchase cocoa delicious easy make daughter cocoa quickly sitting watch movie add anything add tiny bit milk cool would definitely recommend product purchase
# 실제 요약 : hot cocoa cups
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  cocoa
#
#
# 원문 : use olive everything marinades dressings solid flavour texture
# 실제 요약 : very solid product
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great product
#
#
# 원문 : taste decent little sugary creamy otherwise happy product buying product packaging interesting giant box product float around delivers house
# 실제 요약 : pleased with it
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약 :  very good
#
#
# 원문 : wanted rex got seriously guys get local get ancient straight puppy lost within mins bad dog
# 실제 요약 : what
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 예측 요약 :  good product
#
#
# 원문 : generally think cookies much reason excellent cookies several times year especially christmas seem right lot around everyone nibble tried lot different shortbread cookies far best
# 실제 요약 : the very best cookies
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 55ms/step
# 예측 요약 :  yummy
#
#
# 원문 : taste like factory like forgot put cinnamon decided sell way gave one tell would doubt could guess cinnamon disappointed course non returnable rip also bought wintergreen ones better could taste wintergreen flavor canceled auto ship cinnamon mints love ones tins great cinnamon flavor signed auto ship instead
# 실제 요약 : what cinnamon
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약 :  not what expected
#
#
# 원문 : waste money kettle brand potato chips bought case case cheddar sour cream cases ended garbage
# 실제 요약 : garbage
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 예측 요약 :  not bad
#
#
# 원문 : mini dachshund puppy busy loves thing treats really small get use zukes minis however grown drag thing place around try get stuff rarely keeps trying
# 실제 요약 : fun but not the way
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 예측 요약 :  great treats
#
#
# 원문 : love toothbrush treats ask want brush teeth jump mile high get help breath much know keeping teeth clean also little expensive side almost everywhere amazon best price thanks amazon
# 실제 요약 : our dogs love them
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great treats
#
#
# 원문 : others mentioned little guys salty dry crunchy bits baked cheese like cheese spills edge frozen pizza burns baking sheet liked flavors taste like cheese unusual flavors seem saltier artificial tasting always scrape little baked bits cheese aluminum foil baking sheets give try
# 실제 요약 : the regular flavors are good
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great taste
#
#
# 원문 : happen love acai blueberries happy juice heck would even use mixer family much one juice clearly made fun earthy perhaps tree let one go settled fresh oj made concentrate everyone happy still get earthy make good
# 실제 요약 : um acquired taste for others
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great product
#
#
# 원문 : disappointed coffee hot chocolate made plastic like taste unit brewing gives smell thought would go away time convenient mess minimal clean make bad taste tried different coffees bad taste returning unit
# 실제 요약 : smells and tastes like plastic
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  not bad
#
#
# 원문 : cats get buzz cosmic even cat toys stuffed catnip doesnt work becoming concerned last container purchased thru amazon floating catnip nothing lady bugs idea quality control concerned keeping eye large container hoping fluke last time
# 실제 요약 : no lady bugs
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약 :  cats love it
#
#
# 원문 : left new orleans moved least could find blue plate grocery store moved state college pa knew would able find blue plate stores happy amazon carries blue plate mayo things cannot live without new orleans coffee chicory blue plate mayo beans least internet find items
# 실제 요약 : best mayo ever
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  great for the go
#
#
# 원문 : first tea superior lipton sold states grateful find source online
# 실제 요약 : lipton yellow label tea
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  not what expected
#
#
# 원문 : really surprised good coffee normally buy starbucks dunkin donuts bag grocery store right quality price little better coffee fresh strong black nutty flavor really like enjoy
# 실제 요약 : good cup of joe
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : salmon pretty tasty little salty side still good tough chew grip price bucks ounces would give stars price lower
# 실제 요약 : tasty but pricy
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약 :  good but not great
#
#
# 원문 : recieved truffles one day shipping customer service top opened jar enjoyed aroma shop
# 실제 요약 : customer
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 예측 요약 :  great price
#
#
# 원문 : extra bold smooth great coffee ordering like extra bold cup certainly fits
# 실제 요약 : tully cups
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : fed cats various grocery store premium cat foods found royal canin best ingredients results cat happy stays healthy weight loves food delivered amazon makes convenient yes pricey vet bills
# 실제 요약 : best cat food
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great for cats with sensitive cat food
#
#
# 원문 : purchased several bags use mad themed baby shower really cute big hit among guests taste piece chocolate even worth eating effect though would purchase
# 실제 요약 : really cute but not the best chocolate
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great product
#
#
# 원문 : today food prices increase quantity quality product format excellent right type water
# 실제 요약 : time but quality high
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  great product
#
#
# 원문 : add amazon prime mix perfect offering st dalfour tea delicious much seems us distributor periodically runs stock another reason like buy pack time amazon
# 실제 요약 : great tea fantastic price
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 예측 요약 :  great tea
#
#
# 원문 : coombs family farms organic maple syrup best market sweet clear smooth amazon price beats local health food store every time stock use lovely sweetener nice flavor twist stores great shelf put fridge opening keeps well fridge
# 실제 요약 : chef
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  maple syrup
#
#
# 원문 : candy makes good treat cocktail party make sure keep kids away packs punch
# 실제 요약 : candy
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  great candy
#
#
# 원문 : new gluten free world still options certainly good choice like blueberry lemon flavors exactly taste like soft cookie nothing bad say tried gluten free market among better choices friend year old really liked gave box
# 실제 요약 : still getting used to gluten free foods
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great gluten free snack
#
#
# 원문 : year old son loves banana yogurt taste like baby foods honest would eat cup
# 실제 요약 : yum
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  great product
#
#
# 원문 : many making huge mess grounds cup onto counter first one thought maybe one bad one seen green mountain brand rarely maybe one boxes third one tossed remainder trash
# 실제 요약 : pods making huge mess
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  terrible
#
#
# 원문 : bees arrived expected packed super securely pictured problem tempting year old niece picked every single one cake ate even served dessert
# 실제 요약 : too
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  great product
#
#
# 원문 : made switch coffee tea last year switch black green year mint jasmine tea right amount caffeine bright floral flavor delicious
# 실제 요약 : best morning tea ever
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약 :  great tea
#
#
# 원문 : drink teas time first time tried pumpkin think new favorite best price anywhere teas
# 실제 요약 : tea best tea
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  great tea
#
#
# 원문 : read someone review said hard keep fresh store food saver canister transfer lock lock container easy access would imagine would stay fresh used lock lock container dog loves love contain calories
# 실제 요약 : them fresh
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  great product
#
#
# 원문 : excellent pre mix tastes like mother made without measuring mess delicious convenient would repurchase
# 실제 요약 : like mother made
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great taste
#
#
# 원문 : wow gluten dairy free diet ideal quick snack something keep purse box partner strict dietary needs seldom something available tastes good come cost digestive system perfect
# 실제 요약 : small of heaven
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약 :  great gluten free snack
#
#
# 원문 : husband loves chocolate covered cherries tasted would eat kind small town could find christmas holidays valentines day found online keep hand year chocolate cherries happy hubby
# 실제 요약 : in love
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 62ms/step
# 예측 요약 :  these are great
#
#
# 원문 : used ordering nibs grinding result richest chocolate one imagine hand left gritty texture pudding made bitter flavor could even major amounts sugar mild hint chocolate first time ever daughter said want chocolate pudding
# 실제 요약 : bitter and very poor taste
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 예측 요약 :  not bad
#
#
# 원문 : convenient product package fancy feast cat food convenient delivered front door comparable price cat food purchased local grocery store favorable way
# 실제 요약 : cat food
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 예측 요약 :  great food
#
#
# 원문 : extra bold coffee one favorites extra bold could compared bold coffee regular coffee brewer
# 실제 요약 : great coffee for keurig brewer
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : son loves give knowing melt mouth choke good
# 실제 요약 : great snacks
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  great snack
#
#
# 원문 : sauce one best tried used jarred well packaged book recipes sauce shines keep case pantry oz size never waste case jars good price premium sauce
# 실제 요약 : one of the best
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  best chili sauce
#
#
# 원문 : product dry cut cat mouth cause bleeding choking product received petco dry bone could compared eating fish without first would feed family fish bones cats family maybe product received usual quality dry dry dry salmon equally dry
# 실제 요약 : this stuff is dangerous
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  great food
#
#
# 원문 : best tasting protein shake ever tried pretty lean calories per gram protein chocolate ice cream vanilla ice cream cookies cream good like vanilla best shakes make dieting lot pleasant reducing hunger keeping protein intake even calories reduced
# 실제 요약 : tastes like yellow cake
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great tasting snack
#
#
# 원문 : glad find hot sauce amazon used buy ton drove rocky point mexico hot sauce found makes everything taste great
# 실제 요약 : the best hot sauce ever
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약 :  great taste
#
#
# 원문 : found wonderful treats pet store dogs love could find pet stores locally went internet thank heaven able find better price
# 실제 요약 : treats
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  great treats
#
#
# 원문 : really good tasting chips unhealthy eat fair amount love flavoring
# 실제 요약 : great tasting chips alternative
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  great chips
#
#
# 원문 : comes like mush right bag reason even gets two stars convenience
# 실제 요약 : disgusting
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 예측 요약 :  great product
#
#
# 원문 : simply put tea incredible would say like tea never really crave tea except one cup hand sitting leather find relaxation flavor rich distinctive couple cups time nearly taste thinking confusing fan bitter flavors brew dark drink straight love surprised price seems inexpensive
# 실제 요약 : tea that me in good way
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  best tea ever
#
#
# 원문 : sons love pasta personally think tinkyada pastas taste better kids like much think fun animal shapes make appealing love letter shaped pasta well wish company made pasta size larger though kids liked smaller size better oh well still like thrilled found amazon local moms store stopped carrying quite time
# 실제 요약 : great for kids
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  great pasta
#
#
# 원문 : introduced product shop california would steak place put ziplock bag marinate really brings good flavor bbq meat soaked spices part really like contain msg
# 실제 요약 : is great for bbq
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약 :  great product
#
#
# 원문 : dogs love put kong toy keeps busy moments good
# 실제 요약 : yummy
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  dogs love it
#
#
# 원문 : would never buy product hulls equal amount popcorn would much better without stuff product probably come bonus pack dental floss maybe discounted coupon water pick
# 실제 요약 : omg
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  popcorn
#
#
# 원문 : know long sat back shelf somewhere old would cook throw half skins damaged clear sign dried beans past prime cannot even return ask refund food returnable find different brand use fifty servings beans throw away
# 실제 요약 : very low quality
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  not what expected
#
#
# 원문 : recently discovered ginger beer like ginger ale spicy gingery picked sounded like spicy good price found sweet grams sugar per serving like fever tree premium ginger beer ounce glass bottles much better
# 실제 요약 : good but
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  too sweet
#
#
# 원문 : coffee outstanding concept wonderful order kcups adds disappointed otherwise would rated five stars
# 실제 요약 : count the cups
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  not good
#
#
# 원문 : dog vet trying sell dental cleaning long time really dog finally vet told see substantial improvement using dental treat daily dog loves dentastix seen tartar begin disappear going give treat anyway might well give one teeth time
# 실제 요약 : affordable teeth
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약 :  great product
#
#
# 원문 : ordered item children church easter church events children important take seriously item items ordered amazon com saved bunches money purchased elsewhere knows
# 실제 요약 : fresh shipping great prices
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  great product but
#
#
# 원문 : purchased chips since much cheaper cost grocery expire months first bags ate stale plus many broken wrote amazon give prompt refund customer service excellent since opened bags seem stale still believe taste fresh ones grocery may try reordering since good deal hopefully give better review next time
# 실제 요약 : chips were stale but my money was
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  stale
#
#
# 원문 : good stuff maybe little hard guess real granola nice vanilla yogurt mixed granola cereal resealable packaging makes sure turn big pile mush
# 실제 요약 : good stuff
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  great snack
#
#
# 원문 : purchased popcorn along popcorn machine church events could happier fact packages contain oil seasoning popcorn one great feature seasoning perfect everyone events loves gets positive comments great item great value
# 실제 요약 : great popcorn great value
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약 :  best popcorn ever
#
#
# 원문 : addicting tastes good particularly like tiny mint leaves candy complaint artificial flavors natural flavors might natural good mints tough find ones natural like
# 실제 요약 : natural mints
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  not as good as the original
#
#
# 원문 : thin crisp fragrant cookies delicious tasty excellent glass cold almond milk hot herbal tea like ginger snaps love ginger snaps
# 실제 요약 : delicious
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  great cookies
#
#
# 원문 : favorite chai drink almost every day work flavor great big tin nice includes perfect sized scoop make cup nice tin instead individual packets add reduce amount powder according preference perfect morning afternoon treat
# 실제 요약 : delicious and easy to make
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 예측 요약 :  best chai chai
#
#
# 원문 : today january th description says incorrect currently unit price comes pack probably expensive local grocery stores value pack
# 실제 요약 : incorrect description
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약 :  not what expected
#
#
# 원문 : mixed terrier dogs prefer treat others one dogs cabinet stored wanting
# 실제 요약 : these are amazing treats and great value
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약 :  dogs love them
#
#
# 원문 : taste gluten free breads leave blah taste except one excellent taste texture let us daughter enjoy bread family makes great pizza
# 실제 요약 : gluten free bread that actually tastes good
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 예측 요약 :  great gluten free pasta
#
#
# 원문 : royal oak gourmet virginia raw shell peanuts pound bags appreciate speedy deliver package however sent raw peanuts without shell item going gift basket love raw peanuts shell time returned requested product always prompt orders past really appreciate first time sent incorrect product make work
# 실제 요약 : incorrect order
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약 :  great deal
#
#
# 원문 : product excellent customer service good recommended product several people
# 실제 요약 : madhava organic nectar
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약 :  great product
#
#
# 원문 : wonderful product add teaspoon cup lemonade adjust taste thanks
# 실제 요약 : strawberry lemonade all summer
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 예측 요약 :  best chai
#
#
# 원문 : product perfect daughter th grade report germany gave away gummi bears show sampling german product lots bears great price
# 실제 요약 : great bears great price
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 예측 요약 :  great
#
#
# 원문 : perfect size snack bag school minus one star glue straws also wrapper boxes annoying
# 실제 요약 : perfect for snack bag
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 예측 요약 :  great snack
#
#
# 원문 : bear great like kind get novelty candy stores much cheaper lb opinion flavors gummy bears much better haribo bears experienced powdery residue melted previous reviewers bears came perfect condition perfect packaging like mini gummy bears suggest give try
# 실제 요약 : delicious little gummy bears
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 예측 요약 :  best gummi bears
#
#
# 원문 : using product dishes call white rice rice mix daughter liked really well second seasoning quite like recipes tried good work seasoning liked idea something cooked quickly whole wheat organic etc
# 실제 요약 : whole wheat pasta
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 예측 요약 :  great rice
#
#
# 원문 : seemed like good deal time found better deals local
# 실제 요약 : pricey
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약 :  great product
#
#
# 원문 : gevalia coffees favorite large cup morning look forward every day tastes great even one evening coffees satisfies coffee craving probably third fourth time ordering morning roast continue order coffee
# 실제 요약 : my favorite coffee
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : caution use ice cubes zevia soda hooked zevia sodas tastes heavy flavored soda seems right amount taste add ice taste seems get watered zevia new soda choice
# 실제 요약 : great taste
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약 :  great taste
